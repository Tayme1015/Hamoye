# %% [markdown]
# # Hamoye Stage A Quiz

# %% [markdown]
# ## Import relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Extracting the Dataset  - Electric Utility Dataset

# %% [markdown]
# ### From the url link

# %%
raw_fuel_data = pd.read_csv("https://bit.ly/HDSC-StageOneDataset")

raw_fuel_data.to_csv("Electric Utility Dataset.csv", index = False) #Save the data to my pc as "Fuel Data"

# %% [markdown]
# ### From the saved folder

# %%
raw_fuel_data = pd.read_csv("Electric Utility Dataset.csv")

# %%
#Display all rows and columns in the dataset
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
#Display first 100 rows of Dataset
raw_fuel_data.head(100)
# Out:
#                   record_id  utility_id_ferc1  report_year  \
# 0     f1_fuel_1994_12_1_0_7                 1         1994
# 1    f1_fuel_1994_12_1_0_10                 1         1994
# 2     f1_fuel_1994_12_2_0_1                 2         1994
# 3     f1_fuel_1994_12_2_0_7                 2         1994
# 4    f1_fuel_1994_12_2_0_10                 2         1994
# 5    f1_fuel_1994_12_2_0_13                 2         1994
# 6     f1_fuel_1994_12_2_1_1                 2         1994
# 7    f1_fuel_1994_12_2_1_10                 2         1994
# 8    f1_fuel_1994_12_2_2_10                 2         1994
# 9     f1_fuel_1994_12_4_0_1                 4         1994
# 10    f1_fuel_1994_12_4_0_2                 4         1994
# 11    f1_fuel_1994_12_4_0_4                 4         1994
# 12    f1_fuel_1994_12_4_0_5                 4         1994
# 13    f1_fuel_1994_12_6_0_1                 6         1994
# 14    f1_fuel_1994_12_6_0_2                 6         1994
# ...

# %%
fuel_data = raw_fuel_data.copy()

# %% [markdown]
# ## Question 3

# %%
fuel_data.groupby(['fuel_type_code_pudl'])['fuel_cost_per_unit_burned'].mean()
# Out:
# fuel_type_code_pudl
# coal         67.421830
# gas          13.659397
# nuclear    4955.157002
# oil         168.877086
# other        18.253856
# waste        19.518122
# Name: fuel_cost_per_unit_burned, dtype: float64

# %% [markdown]
# ## Question 4

# %%
fuel_data.describe(include = "all")
# Out:
#                        record_id  utility_id_ferc1   report_year  \
# count                      29523      29523.000000  29523.000000
# unique                     29523               NaN           NaN
# top     f1_fuel_2001_12_191_1_10               NaN           NaN
# freq                           1               NaN           NaN
# mean                         NaN        118.601836   2005.806050
# std                          NaN         74.178353      7.025483
# min                          NaN          1.000000   1994.000000
# 25%                          NaN         55.000000   2000.000000
# 50%                          NaN        122.000000   2006.000000
# 75%                          NaN        176.000000   2012.000000
# max                          NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %% [markdown]
# ## Question 5

# %%
#Skewness for the fuel quantity burned
fuel_data['fuel_qty_burned'].skew()
# Out:
# 15.851495469109503

# %%
#Kurtosis for the fuel quantity burned
fuel_data['fuel_qty_burned'].kurt()
# Out:
# 651.3694501337732

# %% [markdown]
# ## Question 6

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
per_miss_val = fuel_data['fuel_unit'].isnull().sum() / (fuel_data['fuel_unit'].count() + fuel_data['fuel_unit'].isnull().sum())

print(per_miss_val * 100)
# Out:
# 0.609694136774718

# %% [markdown]
# ## Question 9

# %%
fuel_data.groupby(['report_year','fuel_type_code_pudl'])['fuel_cost_per_unit_burned'].sum()
# Out:
# report_year  fuel_type_code_pudl
# 1994         coal                    14984.572
#              gas                     10792.496
#              nuclear                227983.354
#              oil                      9362.194
#              other                     116.737
#              waste                      52.762
# 1995         coal                    14571.785
#              gas                      9087.905
#              nuclear                384152.639
#              oil                     17858.281
#              other                     183.577
#              waste                    -192.699
# 1996         coal                    12694.803
#              gas                      1467.390
#              nuclear                 66657.887
#              oil                      5357.028
#              other                     160.075
#              waste                      88.092
# 1997         coal                    43742.178
# ...

# %%
per_change = (11902.597 - 14984.572)/14984.572 *100

per_change
# Out:
# -20.567654518260518

# %% [markdown]
# ## Question 10

# %%
fuel_data.groupby(['report_year'])['fuel_cost_per_unit_delivered'].mean()
# Out:
# report_year
# 1994       63.636060
# 1995       32.735269
# 1996     9196.705948
# 1997    11140.197239
# 1998      287.154420
# 1999       25.551627
# 2000      985.362877
# 2001       60.050396
# 2002       47.594361
# 2003       55.663493
# 2004      139.524275
# 2005       41.438184
# 2006       38.657484
# 2007       43.325023
# 2008       58.588197
# 2009      652.694163
# 2010       91.862105
# 2011       59.774667
# 2012       60.994502
# 2013      172.307591
# 2014      192.737183
# 2015      326.535511
# 2016      103.901761
# 2017       46.196861
# 2018      499.269966
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %% [markdown]
# ## Question 8

# %%
corr_fuel_data = fuel_data.corr()
corr_fuel_data
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
corr_fuel = pd.DataFrame(corr_fuel_data.iloc[:,4])
corr_fuel
# Out:
#                               fuel_cost_per_unit_burned
# utility_id_ferc1                              -0.037863
# report_year                                    0.013599
# fuel_qty_burned                               -0.018535
# fuel_mmbtu_per_unit                           -0.010034
# fuel_cost_per_unit_burned                      1.000000
# fuel_cost_per_unit_delivered                   0.011007
# fuel_cost_per_mmbtu                           -0.000437

# %%
corr_fuel.nsmallest(3,'fuel_cost_per_unit_burned')
# Out:
#                      fuel_cost_per_unit_burned
# utility_id_ferc1                     -0.037863
# fuel_qty_burned                      -0.018535
# fuel_mmbtu_per_unit                  -0.010034
